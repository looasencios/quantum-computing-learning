# %%
"""
Module: 01_mi_primer_circuito_cuantico.ipynb
Autor: Tommy Loo Asencios
Fecha: Agosto 2026
Propósito: Basic Demonstration of the creation of a qubit in superposition state using the Hadamard gate on Qiskit.
"""
# Out:
# '\nModule: 01_mi_primer_circuito_cuantico.ipynb\nAutor: Tommy Loo Asencios\nFecha: Agosto 2026\nPropósito: Basic Demonstration of the creation of a qubit in superposition state using the Hadamard gate on Qiskit.\n'

# %%
import matplotlib.pyplot as plt
from qiskit import QuantumCircuit
qc = QuantumCircuit(1, 1)
# We put the qubit on superposition (50% of probability for 0 and 1)
qc.h(0)
qc.measure(0, 0)
fig = qc.draw(output='mpl')
display(fig)
